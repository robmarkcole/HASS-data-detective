# %%
from HASS_data_detective import DataParser 
from helpers import load_url
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# Using auto reload magic to reload the parser every time it is called.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
with open('C:/Users/Will Koehrsen/Desktop/db_url.txt', 'r') as f:
    db_url = f.read()

# %%
parser = DataParser(db_url)

# %%
parser.list_sensors
# Out:
# ['sensor.bme680humidity',
#  'sensor.bme680pressure',
#  'sensor.next_train_in',
#  'sensor.living_room_temperature',
#  'sensor.darksky_sensor_temperature',
#  'sensor.mean_temperature',
#  'sensor.bme680temperature',
#  'sensor.bedroom_temperature',
#  'sensor.next_train_to_wim',
#  'sensor.network_up',
#  'sensor.home_to_waterloo',
#  'sensor.memory_usage_real',
#  'sensor.cpu_load_total',
#  'sensor.speedtest_download',
#  'sensor.home_to_work',
#  'sensor.work_to_home',
#  'sensor.bayes_probability',
#  'sensor.hall_temperature',
#  'sensor.bme680air_qual',
#  'sensor.darksky_sensor_precip_probability',
#  'sensor.iphone_battery_level',
#  'sensor.robins_iphone_battery_level',
#  'sensor.electric_charger_distance',
#  'sensor.blink_blink_camera_percy_temperature',
#  'sensor.blink_blink_camera_percy_notifications',
#  'sensor.volume_used_volume_1',
#  'sensor.time_in_bed',
#  'sensor.homeassistant_v2db']

# %%
parser.all_corrs()
# Out:
#                                                            value
# sensor.bayes_probability-sensor.bedroom_tempera...  2.722878e-02
# sensor.bayes_probability-sensor.blink_blink_cam...  1.064812e-01
# sensor.bayes_probability-sensor.bme680humidity      1.434322e-13
# sensor.bayes_probability-sensor.bme680pressure      1.451182e-13
# sensor.bayes_probability-sensor.bme680temperature  -1.451216e-13
# sensor.bayes_probability-sensor.cpu_load_total      1.262349e-01
# sensor.bayes_probability-sensor.darksky_sensor_... -1.275836e-02
# sensor.bayes_probability-sensor.darksky_sensor_...  2.550596e-01
# sensor.bayes_probability-sensor.electric_charge... -1.576962e-13
# sensor.bayes_probability-sensor.hall_temperature    1.865766e-01
# sensor.bayes_probability-sensor.home_to_waterloo    4.202230e-01
# sensor.bayes_probability-sensor.home_to_work       -7.974308e-02
# sensor.bayes_probability-sensor.homeassistant_v2db -1.515993e-13
# ...

# %%
volume = pd.DataFrame(parser.get_sensors['sensor.volume_used_volume_1'])

# %%
plt.plot(volume)

# %%
phone = parser.get_sensors['sensor.robins_iphone_battery_level']

# %%
phone.head()
# Out:
# last_changed
# 2018-01-23 07:16:58.762162    100.0
# 2018-01-23 07:16:58.910505    100.0
# 2018-01-23 07:16:59.094701    100.0
# 2018-01-23 07:17:04.256479    100.0
# 2018-01-23 07:17:04.484865    100.0
# Name: sensor.robins_iphone_battery_level, dtype: float64

# %%
phone.tail()
# Out:
# last_changed
# 2018-01-25 02:34:50.335842    74.0
# 2018-01-25 02:36:46.794072    74.0
# 2018-01-25 02:36:46.798116    74.0
# 2018-01-25 02:36:55.787445    74.0
# 2018-01-25 02:36:55.790693    74.0
# Name: sensor.robins_iphone_battery_level, dtype: float64

# %%
model, future = parser.prophet_model(sensor='sensor.robins_iphone_battery_level', freq='M')
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
model.plot(future)

# %%
model.plot_components(future)
